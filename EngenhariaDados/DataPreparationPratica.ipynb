# %% [markdown]
# <a href="https://colab.research.google.com/github/FabricioCruzDev/AnaliseDeDados/blob/master/EngenhariaDados/DataPreparationPratica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import

from google.colab import files
# Out:
#      <input type="file" id="files-2cecad36-81b9-45a8-8c12-f30bc1967475" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2cecad36-81b9-45a8-8c12-f30bc1967475">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# bibliotecas

import pandas as pd
import numpy as np

# %%
df  = pd.read_csv("/content/drive/MyDrive/PosGraduacao/CRISP-DM/data/DataPrepFinal.csv")

# %%
df.head()
# Out:
#    Unnamed: 0          ID                                               name  \
# 0           0  1000002330                    The Songs of Adelaide & Abullah
# 1           1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2           2  1000004038                                     Where is Hank?
# 3           3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4           4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency  deadline     goal        launched  \
# 0          Poetry    Publishing      GBP  09/10/15   100000  11/08/15 12:12
# 1  Narrative Film  Film & Video      USD  01/11/17  3000000  02/09/17 04:43
# 2  Narrative Film  Film & Video      USD  26/02/13  4500000  12/01/13 00:20
# 3           Music         Music      USD  16/04/12   500000  17/03/12 03:24
# 4    Film & Video  Film & Video      USD  29/08/15  1950000  04/07/15 08:35
#
# ...

# %%
df_clean = df.drop(columns = ['Unnamed: 0', 'name', 'category', 'goal', 'pledged', 'usd pledged'])

# %%
df_clean.head()
# Out:
#            ID main_category currency  deadline        launched     state  \
# 0  1000002330    Publishing      GBP  09/10/15  11/08/15 12:12    failed
# 1  1000003930  Film & Video      USD  01/11/17  02/09/17 04:43    failed
# 2  1000004038  Film & Video      USD  26/02/13  12/01/13 00:20    failed
# 3  1000007540         Music      USD  16/04/12  17/03/12 03:24    failed
# 4  1000011046  Film & Video      USD  29/08/15  04/07/15 08:35  canceled
#
#    backers country  usd_pledged_real usd_goal_real
# 0        0      GB                 0    USD 153395
# 1       15      US            242100   USD 3000000
# 2        3      US             22000   USD 4500000
# 3        1      US               100    USD 500000
# 4       14      US            128300   USD 1950000

# %%
df_clean.dtypes
# Out:
# ID                   int64
# main_category       object
# currency            object
# deadline            object
# launched            object
# state               object
# backers              int64
# country             object
# usd_pledged_real     int64
# usd_goal_real       object
# dtype: object

# %%
df_clean['usd_goal_real'] = df_clean['usd_goal_real'].apply(lambda x: x.strip('USD '))

# %%
#usando replace com regex
df_clean['launched'] = df_clean['launched'].str.replace(' \d\d:\d\d', '', regex=True)

# %%
df_clean.head()
# Out:
#            ID main_category currency  deadline  launched     state  backers  \
# 0  1000002330    Publishing      GBP  09/10/15  11/08/15    failed        0
# 1  1000003930  Film & Video      USD  01/11/17  02/09/17    failed       15
# 2  1000004038  Film & Video      USD  26/02/13  12/01/13    failed        3
# 3  1000007540         Music      USD  16/04/12  17/03/12    failed        1
# 4  1000011046  Film & Video      USD  29/08/15  04/07/15  canceled       14
#
#   country  usd_pledged_real usd_goal_real
# 0      GB                 0        153395
# 1      US            242100       3000000
# 2      US             22000       4500000
# 3      US               100        500000
# 4      US            128300       1950000

# %%
df_clean['usd_goal_real'] = df_clean['usd_goal_real'].astype('int')

# %%
df_clean.dtypes
# Out:
# ID                   int64
# main_category       object
# currency            object
# deadline            object
# launched            object
# state               object
# backers              int64
# country             object
# usd_pledged_real     int64
# usd_goal_real        int64
# dtype: object

# %%
df_clean['deadline']  = pd.to_datetime(df_clean['deadline'], format='%d/%m/%y')
df_clean['launched']  = pd.to_datetime(df_clean['launched'], format='%d/%m/%y')
df_clean.dtypes
# Out:
# ID                           int64
# main_category               object
# currency                    object
# deadline            datetime64[ns]
# launched            datetime64[ns]
# state                       object
# backers                      int64
# country                     object
# usd_pledged_real             int64
# usd_goal_real                int64
# dtype: object

# %%
df_clean['time_range'] = (df_clean['deadline'] - df_clean['launched']).dt.days
df_clean
# Out:
#                ID main_category currency   deadline   launched       state  \
# 0      1000002330    Publishing      GBP 2015-10-09 2015-08-11      failed
# 1      1000003930  Film & Video      USD 2017-11-01 2017-09-02      failed
# 2      1000004038  Film & Video      USD 2013-02-26 2013-01-12      failed
# 3      1000007540         Music      USD 2012-04-16 2012-03-17      failed
# 4      1000011046  Film & Video      USD 2015-08-29 2015-07-04    canceled
# ...           ...           ...      ...        ...        ...         ...
# 19458  1098725026   Photography      USD 2015-09-25 2015-07-27      failed
# 19459  1098726927    Publishing      USD 2014-11-07 2014-10-06      failed
# 19460  1098729640         Music      USD 2011-04-30 2011-03-31      failed
# 19461    10987305  Film & Video      USD 2014-06-17 2014-04-18      failed
# 19462  1098735707        Design      USD 2012-01-15 2011-12-05  successful
#
#        backers country  usd_pledged_real  usd_goal_real  time_range
# ...

# %%
dfc = pd.read_csv('/content/drive/MyDrive/PosGraduacao/CRISP-DM/data/campaign.csv')
dfc
# Out:
#                ID  Text Description  Video  Image  Infographic  Reviews  Risks
# 0      1000002330                 1      1      1            1        0      1
# 1      1000003930                 1      1      1            1        1      0
# 2      1000004038                 1      0      1            1        0      1
# 3      1000007540                 1      1      0            1        0      0
# 4      1000011046                 1      0      1            0        0      0
# ...           ...               ...    ...    ...          ...      ...    ...
# 19458  1098725026                 1      0      0            0        0      1
# 19459  1098726927                 1      1      0            1        0      0
# 19460  1098729640                 1      1      1            1        1      1
# 19461    10987305                 1      1      0            0        0      0
# 19462  1098735707                 1      0      1            1        1      1
#
# ...

# %%
dfc['Text Description'].unique()
# Out:
# array([1])

# %%
df_c = dfc.drop(columns=['Text Description'])

# %%
df = df_clean.merge(df_c, how='right', on=['ID'])
df
# Out:
#                ID main_category currency   deadline   launched       state  \
# 0      1000002330    Publishing      GBP 2015-10-09 2015-08-11      failed
# 1      1000003930  Film & Video      USD 2017-11-01 2017-09-02      failed
# 2      1000004038  Film & Video      USD 2013-02-26 2013-01-12      failed
# 3      1000007540         Music      USD 2012-04-16 2012-03-17      failed
# 4      1000011046  Film & Video      USD 2015-08-29 2015-07-04    canceled
# ...           ...           ...      ...        ...        ...         ...
# 19458  1098725026   Photography      USD 2015-09-25 2015-07-27      failed
# 19459  1098726927    Publishing      USD 2014-11-07 2014-10-06      failed
# 19460  1098729640         Music      USD 2011-04-30 2011-03-31      failed
# 19461    10987305  Film & Video      USD 2014-06-17 2014-04-18      failed
# 19462  1098735707        Design      USD 2012-01-15 2011-12-05  successful
#
# ...

# %%
df_i = pd.read_csv('/content/drive/MyDrive/PosGraduacao/CRISP-DM/data/invested.csv')
df_i
# Out:
#                ID backedLocation  age
# 0      1000003930             BR   18
# 1      1000004038             US   57
# 2      1000007540             US   43
# 3      1000011046             BR   29
# 4      1000014025             BR   77
# ...           ...            ...  ...
# 35391  1098718520             US   68
# 35392  1098726927             BR   30
# 35393  1098729640             US   20
# 35394    10987305             BR   19
# 35395  1098735707             US   63
#
# [35396 rows x 3 columns]

# %%
df_i.sort_values(by =['ID'])
# Out:
#                ID backedLocation  age
# 27400      106144             US   63
# 10585      106144            GBK   70
# 17409     1003381             BR   68
# 594       1003381             US   29
# 2925      1017454             US   62
# ...           ...            ...  ...
# 16812  1098729640            GBK   61
# 33627  1098729640            GBK   43
# 16814  1098735707             BR   66
# 33629  1098735707             US   62
# 35395  1098735707             US   63
#
# [35396 rows x 3 columns]

# %% [markdown]
# Há mais de um registro por ID (projeto).

# %%
# Usar o one hot in code(get_dummies)
df_i = pd.get_dummies(df_i, columns=['backedLocation'], dtype= int)
df_i.head()
# Out:
#            ID  age  backedLocation_BR  backedLocation_GBK  backedLocation_US
# 0  1000003930   18                  1                   0                  0
# 1  1000004038   57                  0                   0                  1
# 2  1000007540   43                  0                   0                  1
# 3  1000011046   29                  1                   0                  0
# 4  1000014025   77                  1                   0                  0

# %%
df_i = df_i.groupby(by=['ID']).agg({'age':'mean', 'backedLocation_BR':'sum', 'backedLocation_GBK':'sum', 'backedLocation_US':'sum', })

# %%
df = df.merge(df_i, how='right', on=['ID'])
df.head()
# Out:
#         ID main_category currency   deadline   launched       state  backers  \
# 0   106144         Music      USD 2014-06-15 2014-05-16      failed        1
# 1  1003381         Music      USD 2012-07-19 2012-06-21      failed       30
# 2  1017454  Film & Video      USD 2015-04-26 2015-04-20  successful        9
# 3  1024013    Publishing      USD 2012-05-18 2012-04-03      failed      136
# 4  1024208    Technology      USD 2014-09-11 2014-08-12      failed        5
#
#   country  usd_pledged_real  usd_goal_real  time_range  Video  Image  \
# 0      US              1500         180000          30      1      1
# 1      US            115900        1000000          28      0      1
# 2      US             16700            100           6      1      0
# 3      US            975805        4000000          45      1      1
# 4      US             15000         150000          30      0      1
#
#    Infographic  Reviews  Risks   age  backedLocation_BR  backedLocation_GBK  \
# ...
